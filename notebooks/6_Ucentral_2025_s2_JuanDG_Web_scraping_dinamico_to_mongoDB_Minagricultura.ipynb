# %% [markdown]
# # **Taller de Web Scraping Dinámico y Pipeline ETL**
#
# ##**Normatividad del Ministerio de Agricultura**
#
# *   Autor: Juan Carlos Díaz González
# *   Fecha: 2025-11-18
# ---
# Este cuaderno implementa un pipeline ETL (Extracción, Transformación y Carga) robusto para obtener normatividad pública del sitio web del Ministerio de Agricultura de Colombia y almacenar el contenido textual en MongoDB Atlas.
#
# ### **Flujo de Trabajo (Pipeline)**
#
# 1. **Configuración:** Instalación de librerías, dependencias de OCR (Poppler) y montaje de Google Drive.
# 2. **Scraping:** Navegación dinámica (Playwright) y extracción de todas las URLs de PDF de los módulos definidos.
# 3. **Descarga:** Descarga de archivos PDF, incluyendo validación para descartar archivos corruptos (HTML/Error).
# 4. **Extracción:** Extracción de texto de PDF a formato JSON, con *fallback* a **OCR** para documentos basados en imagen.
# 5. **Carga:** Carga de los archivos JSON a una única colección en MongoDB Atlas, implementando validación de idempotencia para evitar duplicados.
# ---

# %% [markdown]
# # **1. Configuración**
#
# - Instalar librerías y dependencias
# - Instancias librerías
# - Instanciar Google Drive

# %%
# !pip install --upgrade pip
# !apt-get update

# %%
# Instalar dependencias para Playwright
# !apt-get install -y libgbm-dev libnss3-dev libxss-dev libasound2 libatk1.0-0 libatk-bridge2.0-0 libgtk-3-0
# Instalar Playwright para el scraping dinámico.
# !pip install playwright
# !playwright install chromium --with-deps

# %%
# Instalar librerías para trabajar con PDFs y OCR
# !apt-get install -y poppler-utils
# !pip install pdfminer.six pdf2image pytesseract
# !apt-get install tesseract-ocr libtesseract-dev tesseract-ocr-spa
# !apt-get install poppler-utils

# %%
# Instalar librerías para trabajar con imágenes
# !pip install pytesseract Pillow
# !pip install matplotlib-venn

# %%
# Instalar librerías de Mongo
# !pip install pymongo
# !pip install py2neo

# %%
# Instancias librerías
import os
import json
import re
import asyncio # Necesario para ejecutar funciones asíncronas
import pytesseract
import requests
from datetime import datetime
from urllib.parse import urljoin
from io import StringIO
from PIL import Image, ImageOps
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from pymongo import MongoClient
from pymongo.errors import PyMongoError
from google.colab import drive
from playwright.sync_api import sync_playwright
from playwright.async_api import async_playwright, TimeoutError
from pdfminer.high_level import extract_text
from pdf2image import convert_from_path
from requests.exceptions import RequestException

# %%
# Habilitamos Drive de Google desde Colab
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **2. Scraping Dinámico y Extracción de URLs**
#
# La estrategia es un bucle principal que define las rutas de guardado y las colecciones de MongoDB de forma dinámica, con una única función de scraping dinámico, y el cuerpo principal será la iteración.

# %%
# 1. VARIABLES GLOBALES (MINAGRICULTURA)

BASE_URL_RAIZ = "https://www.minagricultura.gov.co"
URL_BASE_NORM = BASE_URL_RAIZ + "/Normatividad/SitePages/buscador-general-normas.aspx"

# Módulos a explorar (Nombre descriptivo: URL completa). Se define la URL de inicio para cada tipo de documento.
MODULOS_MINAGRICULTURA = {
    'Leyes': URL_BASE_NORM + '?t=2',
    'Decretos': URL_BASE_NORM + '?t=4',
    'Resoluciones': URL_BASE_NORM + '?t=3',
    'Conpes': URL_BASE_NORM + '?t=1'
}

# Ruta base para guardar los resultados en Google Drive
BASE_DRIVE_PATH = '/content/drive/MyDrive/BIG_DATA/WebScraping/MinAgricultura_Normatividad/'

# %%
# Función de Scraping Dinámico (Extracción de Hipervínculos)
# Esta función implementa el Scraping Dinámico Asíncrono mediante Playwright para gestionar la paginación.
# Se busca y extrae directamente todos los hipervínculos que terminan en .pdf (a[href$='.pdf']) en cada página,
# aprovechando que los enlaces de descarga son visibles en el DOM principal.
async def extraer_hipervinculos_minagricultura(url_base):
    """
    Navega por una única URL de normatividad, maneja la paginación y extrae
    directamente los enlaces a PDF.
    """
    pdf_links = set()
    BASE_URL_RAIZ = "https://www.minagricultura.gov.co"

    PDF_LINK_SELECTOR = 'a[href$=".pdf"]'                                       # Buscamos enlaces que terminan en .pdf
    NEXT_PAGE_SELECTOR = 'a[title="Siguiente"]'                                 # Selector del botón/enlace de la página siguiente

    print(f"-> Iniciando scraping ASÍNCRONO y paginación...")

    try:
        async with async_playwright() as p:
            browser = await p.chromium.launch(headless=True)
            page = await browser.new_page()

            current_url = url_base
            page_count = 0

            while current_url:
                page_count += 1

                print(f"\nVisitando página {page_count}: {current_url}")
                await page.goto(current_url, wait_until="load", timeout=60000)
                await page.wait_for_timeout(4000)                               # Damos tiempo extra para que cargue la lista de documentos después de la URL

                # 1. EXTRACCIÓN DE ENLACES PDF
                link_elements = await page.locator(PDF_LINK_SELECTOR).all()

                if link_elements:
                    print(f"   {len(link_elements)} enlaces PDF encontrados en esta página.")
                    for link_element in link_elements:
                        href = await link_element.get_attribute("href")
                        if href:
                            full_url = urljoin(BASE_URL_RAIZ, href)             # Construimos la URL completa y la guardamos
                            # FILTRO DE RESTRICCIÓN DE RUTA
                            # Nos aseguramos de que la URL pertenezca al dominio 'Normatividad'
                            if "Normatividad" in full_url or "Leyes" in full_url or "Decretos" in full_url or "Resoluciones" in full_url:
                                pdf_links.add(full_url)
                            else:
                                print(f"   -> [IGNORADO] Enlace fuera de alcance: {full_url}")   # Opcional: imprimir qué enlaces se están ignorando
                                pass
                else:
                    print("   -> No se encontraron enlaces PDF en esta página.")

                # 2. BÚSQUEDA DE PAGINACIÓN
                next_button = page.locator(NEXT_PAGE_SELECTOR).first

                if await next_button.count() > 0 and await next_button.is_visible():
                    next_href = await next_button.get_attribute("href")         # Obtenemos el href del botón Siguiente para la siguiente iteración

                    if next_href and next_href != current_url:                  # Comprobación de ciclo infinito
                        current_url = urljoin(BASE_URL_RAIZ, next_href)
                        print("   -> Paginando a la página siguiente...")
                    else:
                        print("   -> Paginación finalizada o error de URL. Deteniendo el bucle.")
                        current_url = None # Detiene el bucle
                else:
                    print("   -> No se encontró botón 'Siguiente'. Fin de la paginación.")
                    current_url = None                                          # Detiene el bucle
            await browser.close()

    except Exception as e:
        print(f"Error CRÍTICO durante el scraping o paginación: {e}")

    print(f"\n-> Enlaces PDF ÚNICOS encontrados en total: {len(pdf_links)}")
    return list(pdf_links)

# %%
# Bucle Principal de Ejecución. Este es el cuerpo principal con la lógica de visita de páginas.

async def ejecutar_flujo_principal(MODULOS, BASE_DRIVE_PATH):
    """
    Controla la ejecución de scraping, iniciando con las URLs predefinidas en MODULOS.
    """
    all_pdf_links_by_module = {}

    # MODULOS es un diccionario (ej: {'Leyes': 'URL_LEYES'})
    print(f"Tipos de Normatividad a procesar: {', '.join(MODULOS.keys())}")

    for modulo_nombre, url_inicio in MODULOS.items():

        pdf_dir = os.path.join(BASE_DRIVE_PATH, modulo_nombre, 'pdfs')
        json_output_dir = os.path.join(BASE_DRIVE_PATH, modulo_nombre, 'json')
        links_file_path = os.path.join(json_output_dir, 'links.json')

        os.makedirs(pdf_dir, exist_ok=True)
        os.makedirs(json_output_dir, exist_ok=True)

        print(f"\n--- INICIANDO MÓDULO: {modulo_nombre} ---")
        print(f"URL de inicio: {url_inicio}")

        # Extracción de hipervínculos (No necesita recursividad)
        links = await extraer_hipervinculos_minagricultura(url_inicio)
        all_pdf_links_by_module[modulo_nombre] = links

        # Código para guardar links.json
        if links:
            try:
                with open(links_file_path, 'w', encoding='utf-8') as f:
                    json.dump(links, f, indent=4, ensure_ascii=False)
                print(f"[ÉXITO] {len(links)} enlaces guardados en {links_file_path} para {modulo_nombre}")
            except Exception as e:
                print(f"[ERROR] No se pudo guardar links.json para {modulo_nombre}: {e}")
        else:
            print(f"[ADVERTENCIA] No se encontraron enlaces para el módulo {modulo_nombre}.")

    return all_pdf_links_by_module

# %%
# EJECUCIÓN DEL FLUJO PRINCIPAL
#asyncio.run(ejecutar_flujo_principal(MODULOS_MINAGRICULTURA, BASE_DRIVE_PATH))
all_pdf_links_by_module = await ejecutar_flujo_principal(MODULOS_MINAGRICULTURA, BASE_DRIVE_PATH)
# Out:
# Tipos de Normatividad a procesar: Leyes, Decretos, Resoluciones, Conpes
#
# --- INICIANDO MÓDULO: Leyes ---
# URL de inicio: https://www.minagricultura.gov.co/Normatividad/SitePages/buscador-general-normas.aspx?t=2
# -> Iniciando scraping ASÍNCRONO y paginación...
#
# Visitando página 1: https://www.minagricultura.gov.co/Normatividad/SitePages/buscador-general-normas.aspx?t=2
#    123 enlaces PDF encontrados en esta página.
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/Documents/Manual_de_Funciones_y_Competencias_Resoluci%C3%B3n_000417_del_07_de_Noviembre_de_2018.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/ministerio/recursos-humanos/Actos_Administrativos/MODIFICACION%20AL%20MANUAL%20ESPECIFICO%20DE%20FUNCIONES%20Y%20COMPETENCIAS%20LABORALES.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/Documents/Resolucion%2000043%20DE%202023.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/Paginas/Seguridad/DE-GGT-03%20Pol%C3%ADtica%20de%20Seguridad%20y%20Privacidad%20de%20la%20Informaci%C3%B3n%20V4.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/SIG/DocumentosSIG/4GESTION-Y-GOBIERNO-TI/Pol%C3%ADtica-Tratamiento-Datos-Personales-V4.pdf
#    -> No se encontró botón 'Siguiente'. Fin de la paginación.
#
# -> Enlaces PDF ÚNICOS encontrados en total: 60
# [ÉXITO] 60 enlaces guardados en /content/drive/MyDrive/BIG_DATA/WebScraping/MinAgricultura_Normatividad/Leyes/json/links.json para Leyes
#
# --- INICIANDO MÓDULO: Decretos ---
# URL de inicio: https://www.minagricultura.gov.co/Normatividad/SitePages/buscador-general-normas.aspx?t=4
# -> Iniciando scraping ASÍNCRONO y paginación...
#
# Visitando página 1: https://www.minagricultura.gov.co/Normatividad/SitePages/buscador-general-normas.aspx?t=4
#    107 enlaces PDF encontrados en esta página.
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/Documents/Manual_de_Funciones_y_Competencias_Resoluci%C3%B3n_000417_del_07_de_Noviembre_de_2018.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/ministerio/recursos-humanos/Actos_Administrativos/MODIFICACION%20AL%20MANUAL%20ESPECIFICO%20DE%20FUNCIONES%20Y%20COMPETENCIAS%20LABORALES.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/Documents/Resolucion%2000043%20DE%202023.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/Paginas/Seguridad/DE-GGT-03%20Pol%C3%ADtica%20de%20Seguridad%20y%20Privacidad%20de%20la%20Informaci%C3%B3n%20V4.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/SIG/DocumentosSIG/4GESTION-Y-GOBIERNO-TI/Pol%C3%ADtica-Tratamiento-Datos-Personales-V4.pdf
#    -> No se encontró botón 'Siguiente'. Fin de la paginación.
#
# -> Enlaces PDF ÚNICOS encontrados en total: 102
# [ÉXITO] 102 enlaces guardados en /content/drive/MyDrive/BIG_DATA/WebScraping/MinAgricultura_Normatividad/Decretos/json/links.json para Decretos
#
# --- INICIANDO MÓDULO: Resoluciones ---
# URL de inicio: https://www.minagricultura.gov.co/Normatividad/SitePages/buscador-general-normas.aspx?t=3
# -> Iniciando scraping ASÍNCRONO y paginación...
#
# Visitando página 1: https://www.minagricultura.gov.co/Normatividad/SitePages/buscador-general-normas.aspx?t=3
#    103 enlaces PDF encontrados en esta página.
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/Documents/Manual_de_Funciones_y_Competencias_Resoluci%C3%B3n_000417_del_07_de_Noviembre_de_2018.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/ministerio/recursos-humanos/Actos_Administrativos/MODIFICACION%20AL%20MANUAL%20ESPECIFICO%20DE%20FUNCIONES%20Y%20COMPETENCIAS%20LABORALES.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/Documents/Resolucion%2000043%20DE%202023.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/Paginas/Seguridad/DE-GGT-03%20Pol%C3%ADtica%20de%20Seguridad%20y%20Privacidad%20de%20la%20Informaci%C3%B3n%20V4.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/SIG/DocumentosSIG/4GESTION-Y-GOBIERNO-TI/Pol%C3%ADtica-Tratamiento-Datos-Personales-V4.pdf
#    -> No se encontró botón 'Siguiente'. Fin de la paginación.
#
# -> Enlaces PDF ÚNICOS encontrados en total: 98
# [ÉXITO] 98 enlaces guardados en /content/drive/MyDrive/BIG_DATA/WebScraping/MinAgricultura_Normatividad/Resoluciones/json/links.json para Resoluciones
#
# --- INICIANDO MÓDULO: Conpes ---
# URL de inicio: https://www.minagricultura.gov.co/Normatividad/SitePages/buscador-general-normas.aspx?t=1
# -> Iniciando scraping ASÍNCRONO y paginación...
#
# Visitando página 1: https://www.minagricultura.gov.co/Normatividad/SitePages/buscador-general-normas.aspx?t=1
#    33 enlaces PDF encontrados en esta página.
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/Documents/Manual_de_Funciones_y_Competencias_Resoluci%C3%B3n_000417_del_07_de_Noviembre_de_2018.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/ministerio/recursos-humanos/Actos_Administrativos/MODIFICACION%20AL%20MANUAL%20ESPECIFICO%20DE%20FUNCIONES%20Y%20COMPETENCIAS%20LABORALES.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/Documents/Resolucion%2000043%20DE%202023.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/Paginas/Seguridad/DE-GGT-03%20Pol%C3%ADtica%20de%20Seguridad%20y%20Privacidad%20de%20la%20Informaci%C3%B3n%20V4.pdf
#    -> [IGNORADO] Enlace fuera de alcance: https://www.minagricultura.gov.co/SIG/DocumentosSIG/4GESTION-Y-GOBIERNO-TI/Pol%C3%ADtica-Tratamiento-Datos-Personales-V4.pdf
#    -> No se encontró botón 'Siguiente'. Fin de la paginación.
#
# -> Enlaces PDF ÚNICOS encontrados en total: 28
# [ÉXITO] 28 enlaces guardados en /content/drive/MyDrive/BIG_DATA/WebScraping/MinAgricultura_Normatividad/Conpes/json/links.json para Conpes

# %% [markdown]
# # **3. Descarga de archivos PDF**

# %%
# 3. Descarga de PDFs y Validación de Contenido

# Diccionario para capturar el conteo de descargas por módulo
conteo_descargados_final = {}

# Iterar sobre los módulos y sus enlaces
for modulo_nombre, links in all_pdf_links_by_module.items():

    contador_modulo = 0
    pdf_dir = os.path.join(BASE_DRIVE_PATH, modulo_nombre, 'pdfs')
    json_output_dir = os.path.join(BASE_DRIVE_PATH, modulo_nombre, 'json')

    # 1. Definición del archivo de log
    FALLOS_LOG_PATH = os.path.join(json_output_dir, 'fallos_descarga.log')

    print(f"\n--- Iniciando descarga de {len(links)} documentos para {modulo_nombre} ---")

    # Aseguramos que los directorios existan
    os.makedirs(pdf_dir, exist_ok=True)
    os.makedirs(json_output_dir, exist_ok=True)

    # 2. Abrir el archivo de log en modo 'a' (append)
    with open(FALLOS_LOG_PATH, 'a', encoding='utf-8') as log_file:

        # Escribir encabezado de inicio de ejecución
        log_file.write(f"\n--- INICIO DE EJECUCIÓN: {modulo_nombre} ({os.path.basename(FALLOS_LOG_PATH)}) ---\n")

        for url in links:
            file_name = os.path.basename(url)
            file_path = os.path.join(pdf_dir, file_name)

            # COMPROBACIÓN 1: Idempotencia (Archivo ya existe)
            if os.path.exists(file_path):
                print(f"  -> [SALTAR] Documento ya existe, se salta la descarga: {file_name}") # Mensaje de salto habilitado
                contador_modulo += 1
                continue

            try:
                # 3. Descargar el archivo
                response = requests.get(url, stream=True, timeout=30)
                response.raise_for_status() # Lanza error si es 4xx o 5xx

                # 4. VALIDACIÓN DE CONTENIDO CORRUPTO

                # A. Validar Tipo MIME (Content-Type)
                content_type = response.headers.get('Content-Type', '').lower()
                if 'text/html' in content_type or 'text/plain' in content_type:
                    motivo = f"Descargado como {content_type}. Archivo no es PDF."
                    print(f"[ERROR CORRUPTO]: {file_name}. {motivo}")
                    log_file.write(f"[CORRUPTO - MIME] URL: {url} | Archivo: {file_name} | Motivo: {motivo}\n")
                    continue

                # B. Validar Encabezado Binario (%PDF-)
                if not response.content.startswith(b'%PDF-'):
                    motivo = "No comienza con el encabezado binario '%PDF-'."
                    print(f"[ERROR CORRUPTO]: {file_name}. {motivo}")
                    log_file.write(f"[CORRUPTO - BINARIO] URL: {url} | Archivo: {file_name} | Motivo: {motivo}\n")
                    continue

                # 5. Guardar el archivo (Solo si pasa las validaciones)
                with open(file_path, 'wb') as pdf_file:
                    pdf_file.write(response.content)

                # MENSAJE DE ÉXITO DE DESCARGA
                print(f"[OK] Descargado y validado: {file_name}")
                contador_modulo += 1

            except RequestException as e:
                motivo = f"Error HTTP/Conexión: {e}"
                print(f"[ERROR RED]: {file_name}. {motivo}")
                log_file.write(f"[ERROR RED] URL: {url} | Archivo: {file_name} | Motivo: {motivo}\n")

            except Exception as e:
                motivo = f"Error general desconocido: {e}"
                print(f"[ERROR GENERAL]: {file_name}. {motivo}")
                log_file.write(f"[ERROR GENERAL] URL: {url} | Archivo: {file_name} | Motivo: {motivo}\n")

    # Al finalizar el bucle interno, guardar el conteo del módulo
    conteo_descargados_final[modulo_nombre] = contador_modulo

# RESUMEN FINAL DE DESCARGA
print("\n" + "="*50)
print("RESUMEN FINAL DE DESCARGA DE PDFS")
print("="*50)
for modulo, count in conteo_descargados_final.items():
    total_links = len(all_pdf_links_by_module.get(modulo, []))
    saltados_o_exitosos = count

    print(f"[OK] Módulo {modulo}: {saltados_o_exitosos} documentos procesados (descargados o ya existentes).")
    print(f"   - Total de URLs únicas: {total_links}")
print("="*50)
# Out:
# --- Iniciando descarga de 60 documentos para Leyes ---
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202175%20DEL%2030%20DE%20DICIEMBRE%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%20160%20de%201994.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: ley%202079%20DEL%2014%20DE%20ENERO%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%201133%20de%202007.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%20607%20de%202000.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202204%20DEL%2010%20DE%20MAYO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202138%20DEL%204%20DE%20AGOSTO%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202223%20DEL%2030%20DE%20JUNIO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202169%20DEL%2022%20DE%20DICIEMBRE%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%201900%20DEL%2018%20DE%20JUNIO%20DE%202018.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202227%20DEL%201%20DE%20JULIO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%20101%20de%201993.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202005%20DEL%2002%20DE%20DICIEMBRE%20DE%202019.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202080%20DEL%2025%20DE%20ENERO%20DEL%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202183%20DEL%206%20DE%20ENERO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20000112%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%201561%20de%202012.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%20%20811%20de%202003.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%201448%20de%202011.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202239%20DE%208%20DE%20JULIO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%201847%20DEL%2018%20DE%20JULIO%20DE%202017.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202268%20DE%2003%20DE%20AGOSTO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202281%20DEL%204%20DE%20ENERO%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202022%20DEL%2022%20DE%20JULIO%20DE%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202046%20DEL%206%20DE%20AGOSTO%20DE%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%20797%20de%202003.pdf
# [ERROR CORRUPTO]: LEY%202197%20DEL%2025%20DE%20ENERO%20DE%202022.pdf. No comienza con el encabezado binario '%PDF-'.
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202186%20DEL%206%20DE%20ENERO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202173%20DEL%2030%20DE%20DICIEMBRE%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202337%20DE%20OCTUBRE%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202321%20DE%20SEPTIEMBRE%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%20731%202002.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%2070%20de%201993.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202294%20DEL%2019%20DE%20MAYO%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%201776%20DEL%2029%20DE%20ENERO%20DE%202016.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%201731%20de%202014.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20000111%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%201842%20DEL%2014%20DE%20JULIO%20DE%202017.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202177%20DEL%2030%20DE%20DICIEMBRE%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%201851%20DEL%2019%20DE%20JULIO%20DE%202017.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202249%20DE%2011%20DE%20JULIO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202013%20DEL%2030%20DE%20DICIEMBRE%20DE%202019.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%201955%20DEL%2025%20DE%20MAYO%20DE%202019.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202311%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202071%20DEL%2031%20DE%20DICIEMBRE%20DE%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202331%20DE%20AGOSTO%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%201335%20DE%202009.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%20No%201876%20de%202017.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202285%20DEL%205%20DE%20ENERO%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202008%20DEL%2027%20DE%20DICIEMBRE%20DE%202019.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202219%20DEL%2030%20DE%20JUNIO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202078%20DEL%208%20DE%20ENERO%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Ley%20139%20de%201994.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202303%20DE%20JULIO%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202206%20DEL%2017%20DE%20MAYO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202178%20DEL%2030%20DE%20DICIEMBRE%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%201876%20DEL%2029%20DE%20DICIEMBRE%20DE%202017.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202163%20DEL%207%20DE%20DICIEMBRE%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%202193%20DEL%206%20DE%20ENERO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: LEY%201969%20DEL%2011%20DE%20JULIO%20DE%202019.pdf
#
# --- Iniciando descarga de 102 documentos para Decretos ---
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201139%20DEL%2027%20DE%20OCTUBRE%20DE%202025%20Catastro%20Multipropo%CC%81sito%20Comunidades%20negras.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20417%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20No.%201731%20de%202020.pdf
# [ERROR CORRUPTO]: DECRETO%201406%20DEL%2029%20DE%20AGOSTO%20DE%202023.pdf. No comienza con el encabezado binario '%PDF-'.
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20531%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200389%20DEL%201%20DE%20ABRIL%20DE%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200815%20DE%204%20DE%20JULIO%20DE%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreo%20796%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200531%20DE%2029%20DE%20ABRIL%20DE%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO_0107_DEL_29_ENERO_2025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201612%20DEL%2005%20DE%20AGOSTO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201731%20DEL%2016%20DE%20DICIEMBRE%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%20826%20DEL%2026%20DE%20JULIO%20DE%202021.pdf
# [ERROR CORRUPTO]: Decreto_1322_de_2024_Ministerio_de_Agricultura_y_Desarrollo_Rural.pdf. No comienza con el encabezado binario '%PDF-'.
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%20279%20DEL%2025%20DE%20FEBRERO%20DE%202022.pdf
# [OK] Descargado y validado: DECRETO%201191%20DEL%2012%20DE%20NOVIEMBRE%20DE%202025%20Bienes%20FRV.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%20834%20DEL%2025%20DE%20MAYO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201117%20DEL%2024%20DE%20OCTUBRE%20DE%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20593%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201004%20DE%205%20DE%20AGOSTO%20DE%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200462%20DEL%2022%20DE%20ABRIL%20DE%202025%20Catastro%20multipropo%CC%81sito%20indi%CC%81genas.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200147%20DEL%207%20DE%20FEBRERO%20DE%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20No.%20248%20de%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201834%20DEL%2024%20DE%20DICIEMBRE%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201374%20DEL%2027%20DE%20JULIO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201878%20DEL%2030%20DE%20DICIEMBRE%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200264%20DEL%2027%20DE%20FEBRERO%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20491%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201276%20DEL%2031%20DE%20JULIO%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20465%20del%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201135%20DEL%2027%20DE%20OCTUBRE%20DE%202025%20Funciones%20MADR.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200388%20DEL%201%20DE%20ABRIL%20DE%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201143%20DE%2012%20DE%20SEPTIEMBRE%20DE%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%20115%20DEL%2027%20DE%20ENERO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%201319%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20No.%201678%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20507%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200977%20DE%202%20DE%20AGOSTO%20DE%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200129%20DEL%207%20DE%20FEBRERO%20DE%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%20NO.%20596%20DEL%201%20DE%20JUNIO%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO_0106_DEL_29_ENERO_2025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20000111%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20No.%201701%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO-1020-DE-9-DE-AGOSTO-DE-2024.pdf
# [OK] Descargado y validado: DECRETO%201222%20DEL%2014%20DE%20NOVIEMBRE%20DE%202025%20Medios%20Democra%CC%81ticos.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200780%20DE%2024%20DE%20JUNIO%20DE%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200746%20DE%2011%20DE%20JUNIO%20DE%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO-0724-DE-2024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201249%20DEL%2026%20DE%20JULIO%20DE%202023%20(1).pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%201330%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20440%20del%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201495%20DEL%2013%20DE%20SEPTIEMBRE%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20434%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20211%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Dereto%20803%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%20902%20DEL%2030%20DE%20JUNIO%20DE%202020%20(1).pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201396%20DE%2022%20DE%20NOVIEMBRE%20DE%202024%20(1).pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20527%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201457%20DE%206%20DE%20DICIEMBRE%20DE%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20640%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201106%20DEL%2029%20DE%20JUNIO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%20375%20DEL%2014%20DE%20MARZO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200033%20DEL%2017%20DE%20ENERO%20DE%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20486%20del%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201835%20DEL%2024%20DE%20DICIEMBRE%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200874%20DEL%2031%20DE%20JULIO%20DE%202025%20Apicultura.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200797%20DEL%2009%20DE%20JULIO%20DE%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200245%20DEL%2022%20DE%20FEBRERO%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201730%20DEL%2016%20DE%20DICIEMBRE%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20No.%201824%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201623%20DEL%206%20DE%20OCTUBRE%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200869%20DEL%2031%20DE%20JULIO%20DE%202025%20RROM.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201406%20DEL%2029%20DE%20AGOSTO%20DE%202023%20(1).pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201147%20DE%2013%20DE%20SEPTIEMBRE%20DE%202024%20(1).pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201138%20DEL%2027%20DE%20OCTUBRE%20DE%202025%20Uso%20de%20Cannabis.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%20504%20DEL%204%20DE%20ABRIL%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20000112%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Biosolidos_DECRETO%200774%20DEL%2007%20DE%20JULIO%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20No.%20849%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200180%20DEL%2014%20DE%20FEBRERO%20DE%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20No.%20087%20de%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201130%20DEL%2030%20DE%20JUNIO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201879%20DEL%2030%20DE%20DICIEMBRE%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200971%20DEL%208%20DE%20SEPTIEMBRE%20DE%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%202439%20DEL%2012%20DE%20DICIEMBRE%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20471%20del%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20457%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201649%20DEL%2012%20DE%20OCTUBRE%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200347%20DEL%2025%20DE%20MARZO%20DE%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%201273%20de%202023%20autenticado%20(1)%20(1).pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20637%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20810%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200788%20DE%2027%20DE%20JUNIO%20DE%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%20405%20DEL%2024%20DE%20MARZO%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20No.%20822%20de%202020.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200387%20DEL%2020%20DE%20MARZO%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200670%20DEL%2017%20DE%20JUNIO%20DE%202025%20Basura%20Cero.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%200810%20DEL%2015%20DE%20JULIO%20DE%202025%20(SINAPYBA).pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%201456%20DE%206%20DE%20DICIEMBRE%20DE%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO_0108_DEL_29_ENERO_2025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: DECRETO%202185%20DEL%2018%20DE%20DICIEMBRE%20DE%202023.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Decreto%20636%20de%202020.pdf
#
# --- Iniciando descarga de 98 documentos para Resoluciones ---
#   -> [SALTAR] Documento ya existe, se salta la descarga: Instructivo%20Te%CC%81cnico%20Apoyo%20Directo%20Arroz%20V%202.0%20(21%20de%20julio)%20OK.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000389%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000344%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000378%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RES.%200057%20DE%2017%20ENE%202025%20REGLAMENTA%20ART%2055%20LEY%202294%20(2).pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000212%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000337%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000294%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000347%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000055%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000052%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Resolucion_1721_julio_17_2025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000391%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCIO%CC%81N%20NO%20000295%202025%20ANEXOS.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000330%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000386%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000373%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000016%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000181%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000385%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000023%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000084%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000114%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000125%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000365%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000366%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000175%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000375%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000377%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000394%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000176%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000068%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000241%20de%202025%20(1).pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000096%20de%202025%20Pagra.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000383%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000058%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000345%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Reporte%20de%20Informacio%CC%81n_Resolucio%CC%81n%20241%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: V.4%20Instructivo%20te%CC%81cnico%20programa%20apoyo%20directo%20arroz_VoBo%20Signed%20(1)%20(1).pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000024%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000140%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000313%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Resolucio%CC%81n%20000059%20de%202025%20Transferencia%20FAIA.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20000111%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000331%20de%202024%20-12-12-24.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000372%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000388%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000152%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000180%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000392%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000381%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000339%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000178%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000235%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000396%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000242%20de%202025%20ZPPA%20CORDOBA.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000086%20de%202025%20Mod.%20Res.%20000016-2025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000081%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000174%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000328%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000354%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000382%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000351%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000231%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000182%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000384%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: MANUAL%20OPERATIVO%20PAAP%20V7%20FIRMADO.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000390%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCIO%CC%81N%20NO.%20000327%20DE%202025%20-%20MJ.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000123%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000393%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCIO%CC%81N%20330%20DE%202025%20-ANEXOS.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000352%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000141%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000359%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000214%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000266%20de%202025%20y%20DTS.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000121%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000397%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000169%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000269%20de%202025_ZPPA%20SANTANDER.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000177%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20000112%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Anexo%20T%C3%A9cnico%20-%20Lineamientos%20de%20Pol%C3%ADtica%20P%C3%BAblica.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000320%20de%202025%20y%20DTS.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000289%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000002%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000027%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000331%20de%202024_15_12_2024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000374%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000179%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000085%20de%202025%20Libertad%20vigilada%20arroz.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000380%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000376%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000395%20de%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000356%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000355%20de%202025.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20No.%20000069%20de%202025.pdf
#
# --- Iniciando descarga de 28 documentos para Conpes ---
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%203418%20VERSI%C3%93N%20APROBADA%20EL%202006.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Conpes%20113%20de%202008.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%204076%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%204073%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%204074%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%203940%20de%202018.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%203558%20VERSI%C3%93N%20APROBADA%20EL%202008.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20000112%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%203859%20VERSI%C3%93N%20APROBADA%20EL%202018.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%203316%20VERSI%C3%93N%20APROBADA%20EL%202004.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%203917%20VERSI%C3%93N%20APROVADA%20EL%202018.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%203304%20VERSI%C3%93N%20APROBADA%20EL%202004.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%204069%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Conpes%203616%20de%202009.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%204070%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: RESOLUCION%20000111%202024.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Conpes%203467%20de%202007.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%204066%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: 3958.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%204081%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: conpes%203709%20de%202011.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Conpes%203169%20de%202012.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%204067%20DE%202021.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%203438%20VESI%C3%93N%20APROBADA%20EL%202006.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%204075%20DE%202022.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%203810%20VERSI%C3%93N%20APROBADA%20EL%202014.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: Conpes%203426%20de%202006.pdf
#   -> [SALTAR] Documento ya existe, se salta la descarga: CONPES%204080%20DE%202022.pdf
#
# ==================================================
# RESUMEN FINAL DE DESCARGA DE PDFS
# ==================================================
# [OK] Módulo Leyes: 59 documentos procesados (descargados o ya existentes).
#    - Total de URLs únicas: 60
# [OK] Módulo Decretos: 100 documentos procesados (descargados o ya existentes).
#    - Total de URLs únicas: 102
# [OK] Módulo Resoluciones: 98 documentos procesados (descargados o ya existentes).
#    - Total de URLs únicas: 98
# [OK] Módulo Conpes: 28 documentos procesados (descargados o ya existentes).
#    - Total de URLs únicas: 28
# ==================================================

# %% [markdown]
# # **4. Extracción de Texto de PDF a formato JSON**

# %%
# Extracción de Texto a JSON (OCR Incluido)

# 1. Intentar importar la función de extracción directa (pdfminer.six)
try:
    from pdfminer.high_level import extract_text
    print("[OK] Módulo 'pdfminer.high_level' importado correctamente para extracción directa.")
    PDFMINER_DISPONIBLE = True
except Exception as e:
    print(f"[ERROR] Falló la importación de 'pdfminer.high_level': {e}. Se usará solo OCR.")
    PDFMINER_DISPONIBLE = False

# FUNCIONES DE EXTRACCIÓN

def extract_text_pdfminer(pdf_path):
    """Intenta extraer texto directamente usando pdfminer.six. Si falla, lanza excepción."""
    if not PDFMINER_DISPONIBLE:
        raise ImportError("pdfminer.six no está disponible.")

    texto = extract_text(pdf_path)
    # Si el texto es muy corto, asume que es un PDF de imagen.
    if len(texto.strip()) < 50:
        raise ValueError("Texto extraído es demasiado corto o vacío, probablemente PDF de imagen.")
    return texto

def extract_text_ocr(pdf_path):
    """Extrae texto usando OCR (pdf2image + pytesseract). Captura errores de bajo nivel."""
    print(f"   -> Intentando OCR (esto puede tardar más)...")
    try:
        images = convert_from_path(pdf_path) # Convierte PDF a imágenes

        texto_ocr = []
        for i, image in enumerate(images):
            page_text = pytesseract.image_to_string(image, lang='spa') # Aplica OCR
            texto_ocr.append(page_text)

        return "\n".join(texto_ocr)
    except Exception as e:
        print(f"[ERROR GRAVE OCR]: {e}") # Reporta el error fatal
        return None # Devuelve None para que el bucle lo pueda manejar

def robust_extract_text(pdf_path):
    """Intenta la extracción directa, y si falla, cae al OCR."""
    # 1. Intento de extracción directa
    if PDFMINER_DISPONIBLE:
        try:
            texto = extract_text_pdfminer(pdf_path)
            return texto
        except (ValueError, ImportError, Exception) as e:
             # Si falla (texto corto o PDF corrupto para pdfminer), pasa al OCR.
            pass
    # 2. Fallback a OCR
    texto_ocr = extract_text_ocr(pdf_path)
    if texto_ocr and len(texto_ocr.strip()) > 50:
        return texto_ocr
    else:
        return None

# BUCLE PRINCIPAL DE PROCESAMIENTO

conteo_extraidos_final = {}

for modulo_nombre in MODULOS_MINAGRICULTURA.keys():

    pdf_dir = os.path.join(BASE_DRIVE_PATH, modulo_nombre, 'pdfs')
    json_output_dir = os.path.join(BASE_DRIVE_PATH, modulo_nombre, 'json')

    contador_extraido = 0

    print(f"\n--- Iniciando procesamiento de texto para: {modulo_nombre} ---")

    for file_name in os.listdir(pdf_dir):
        if file_name.endswith('.pdf'):

            pdf_path = os.path.join(pdf_dir, file_name)
            json_file_name = file_name.replace('.pdf', '.json')
            json_path = os.path.join(json_output_dir, json_file_name)

            # 3. Comprobación de idempotencia (si el JSON ya existe, se salta)
            if os.path.exists(json_path):
                print(f"  -> [SKIP] JSON ya existe, se salta el reprocesamiento: {json_file_name}")
                contador_extraido += 1
                continue

            # 4. Extracción de texto robusta
            print(f"Procesando {file_name}...")
            texto_extraido = robust_extract_text(pdf_path)

            if texto_extraido:
                # 5. Crear y guardar el objeto JSON
                documento_json = {
                    "documento_nombre": file_name,
                    "modulo": modulo_nombre,
                    "contenido": texto_extraido,
                    "fecha_extraccion": "2025-11-18" # Usar la fecha actual
                }

                with open(json_path, 'w', encoding='utf-8') as f:
                    json.dump(documento_json, f, indent=4, ensure_ascii=False)

                contador_extraido += 1
                print(f"  -> [OK] Extraído y guardado: {json_file_name}")
            else:
                print(f"[FALLO TOTAL]: No se pudo extraer texto de {file_name}. Saltando.")

    conteo_extraidos_final[modulo_nombre] = contador_extraido

# RESUMEN FINAL
print("\n" + "="*50)
print("RESUMEN FINAL DE EXTRACCIÓN DE TEXTO A JSON")
print("="*50)
for modulo, count in conteo_extraidos_final.items():
    print(f"[OK] Módulo {modulo}: {count} documentos extraídos y guardados como JSON.")
print("="*50)
# Out:
# [OK] Módulo 'pdfminer.high_level' importado correctamente para extracción directa.
#
# --- Iniciando procesamiento de texto para: Leyes ---
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202177%20DEL%2030%20DE%20DICIEMBRE%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202193%20DEL%206%20DE%20ENERO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%2070%20de%201993.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%20731%202002.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202186%20DEL%206%20DE%20ENERO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%201900%20DEL%2018%20DE%20JUNIO%20DE%202018.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%201335%20DE%202009.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%201847%20DEL%2018%20DE%20JULIO%20DE%202017.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202337%20DE%20OCTUBRE%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%201876%20DEL%2029%20DE%20DICIEMBRE%20DE%202017.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%20607%20de%202000.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%20No%201876%20de%202017.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%20%20811%20de%202003.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%201776%20DEL%2029%20DE%20ENERO%20DE%202016.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202013%20DEL%2030%20DE%20DICIEMBRE%20DE%202019.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202249%20DE%2011%20DE%20JULIO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%20160%20de%201994.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202219%20DEL%2030%20DE%20JUNIO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202163%20DEL%207%20DE%20DICIEMBRE%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%201851%20DEL%2019%20DE%20JULIO%20DE%202017.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202294%20DEL%2019%20DE%20MAYO%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%201448%20de%202011.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%20101%20de%201993.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202175%20DEL%2030%20DE%20DICIEMBRE%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202204%20DEL%2010%20DE%20MAYO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202303%20DE%20JULIO%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202005%20DEL%2002%20DE%20DICIEMBRE%20DE%202019.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202178%20DEL%2030%20DE%20DICIEMBRE%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202071%20DEL%2031%20DE%20DICIEMBRE%20DE%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%201731%20de%202014.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%201969%20DEL%2011%20DE%20JULIO%20DE%202019.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202078%20DEL%208%20DE%20ENERO%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%20797%20de%202003.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202008%20DEL%2027%20DE%20DICIEMBRE%20DE%202019.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202285%20DEL%205%20DE%20ENERO%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%201842%20DEL%2014%20DE%20JULIO%20DE%202017.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%20139%20de%201994.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%201561%20de%202012.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202206%20DEL%2017%20DE%20MAYO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202311%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20000112%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202331%20DE%20AGOSTO%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202169%20DEL%2022%20DE%20DICIEMBRE%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Ley%201133%20de%202007.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202281%20DEL%204%20DE%20ENERO%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202268%20DE%2003%20DE%20AGOSTO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202321%20DE%20SEPTIEMBRE%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20000111%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202080%20DEL%2025%20DE%20ENERO%20DEL%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202046%20DEL%206%20DE%20AGOSTO%20DE%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202239%20DE%208%20DE%20JULIO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202227%20DEL%201%20DE%20JULIO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202138%20DEL%204%20DE%20AGOSTO%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202173%20DEL%2030%20DE%20DICIEMBRE%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202223%20DEL%2030%20DE%20JUNIO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202183%20DEL%206%20DE%20ENERO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%202022%20DEL%2022%20DE%20JULIO%20DE%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: ley%202079%20DEL%2014%20DE%20ENERO%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: LEY%201955%20DEL%2025%20DE%20MAYO%20DE%202019.json
#
# --- Iniciando procesamiento de texto para: Decretos ---
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%20405%20DEL%2024%20DE%20MARZO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201612%20DEL%2005%20DE%20AGOSTO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200245%20DEL%2022%20DE%20FEBRERO%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200971%20DEL%208%20DE%20SEPTIEMBRE%20DE%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%20834%20DEL%2025%20DE%20MAYO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%201330%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201835%20DEL%2024%20DE%20DICIEMBRE%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO_0106_DEL_29_ENERO_2025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201495%20DEL%2013%20DE%20SEPTIEMBRE%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%20902%20DEL%2030%20DE%20JUNIO%20DE%202020%20(1).json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%202439%20DEL%2012%20DE%20DICIEMBRE%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200874%20DEL%2031%20DE%20JULIO%20DE%202025%20Apicultura.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20434%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200797%20DEL%2009%20DE%20JULIO%20DE%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20000112%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201106%20DEL%2029%20DE%20JUNIO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%20826%20DEL%2026%20DE%20JULIO%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201731%20DEL%2016%20DE%20DICIEMBRE%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreo%20796%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%202398%20del%202019.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20No.%201701%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200388%20DEL%201%20DE%20ABRIL%20DE%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200810%20DEL%2015%20DE%20JULIO%20DE%202025%20(SINAPYBA).json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20457%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200788%20DE%2027%20DE%20JUNIO%20DE%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20130%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%202185%20DEL%2018%20DE%20DICIEMBRE%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20465%20del%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20486%20del%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20No.%20248%20de%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201406%20DEL%2029%20DE%20AGOSTO%20DE%202023%20(1).json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201249%20DEL%2026%20DE%20JULIO%20DE%202023%20(1).json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201139%20DEL%2027%20DE%20OCTUBRE%20DE%202025%20Catastro%20Multipropo%CC%81sito%20Comunidades%20negras.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO_0108_DEL_29_ENERO_2025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201135%20DEL%2027%20DE%20OCTUBRE%20DE%202025%20Funciones%20MADR.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201649%20DEL%2012%20DE%20OCTUBRE%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%20115%20DEL%2027%20DE%20ENERO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201138%20DEL%2027%20DE%20OCTUBRE%20DE%202025%20Uso%20de%20Cannabis.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%201319%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201730%20DEL%2016%20DE%20DICIEMBRE%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200531%20DE%2029%20DE%20ABRIL%20DE%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20211%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200462%20DEL%2022%20DE%20ABRIL%20DE%202025%20Catastro%20multipropo%CC%81sito%20indi%CC%81genas.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200264%20DEL%2027%20DE%20FEBRERO%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201834%20DEL%2024%20DE%20DICIEMBRE%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20000111%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200033%20DEL%2017%20DE%20ENERO%20DE%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200129%20DEL%207%20DE%20FEBRERO%20DE%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20No.%201678%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200670%20DEL%2017%20DE%20JUNIO%20DE%202025%20Basura%20Cero.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200780%20DE%2024%20DE%20JUNIO%20DE%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200387%20DEL%2020%20DE%20MARZO%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Biosolidos_DECRETO%200774%20DEL%2007%20DE%20JULIO%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20No.%20849%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201456%20DE%206%20DE%20DICIEMBRE%20DE%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20640%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201117%20DEL%2024%20DE%20OCTUBRE%20DE%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20417%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201623%20DEL%206%20DE%20OCTUBRE%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20No.%201824%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200347%20DEL%2025%20DE%20MARZO%20DE%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201878%20DEL%2030%20DE%20DICIEMBRE%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201457%20DE%206%20DE%20DICIEMBRE%20DE%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20440%20del%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201143%20DE%2012%20DE%20SEPTIEMBRE%20DE%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200389%20DEL%201%20DE%20ABRIL%20DE%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20491%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO_0107_DEL_29_ENERO_2025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%20279%20DEL%2025%20DE%20FEBRERO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20593%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20507%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201130%20DEL%2030%20DE%20JUNIO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201396%20DE%2022%20DE%20NOVIEMBRE%20DE%202024%20(1).json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200180%20DEL%2014%20DE%20FEBRERO%20DE%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201276%20DEL%2031%20DE%20JULIO%20DE%202023.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20527%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200869%20DEL%2031%20DE%20JULIO%20DE%202025%20RROM.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201879%20DEL%2030%20DE%20DICIEMBRE%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20810%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20471%20del%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200147%20DEL%207%20DE%20FEBRERO%20DE%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20No.%201731%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20No.%20822%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201374%20DEL%2027%20DE%20JULIO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%20504%20DEL%204%20DE%20ABRIL%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%20NO.%20596%20DEL%201%20DE%20JUNIO%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%201273%20de%202023%20autenticado%20(1)%20(1).json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200746%20DE%2011%20DE%20JUNIO%20DE%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%20375%20DEL%2014%20DE%20MARZO%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO-1020-DE-9-DE-AGOSTO-DE-2024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20637%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20636%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO-0724-DE-2024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200977%20DE%202%20DE%20AGOSTO%20DE%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Dereto%20803%20de%202020.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%200815%20DE%204%20DE%20JULIO%20DE%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201147%20DE%2013%20DE%20SEPTIEMBRE%20DE%202024%20(1).json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20No.%20087%20de%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: DECRETO%201004%20DE%205%20DE%20AGOSTO%20DE%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Decreto%20531%20de%202020.json
# Procesando DECRETO%201191%20DEL%2012%20DE%20NOVIEMBRE%20DE%202025%20Bienes%20FRV.pdf...
#   -> [OK] Extraído y guardado: DECRETO%201191%20DEL%2012%20DE%20NOVIEMBRE%20DE%202025%20Bienes%20FRV.json
# Procesando DECRETO%201222%20DEL%2014%20DE%20NOVIEMBRE%20DE%202025%20Medios%20Democra%CC%81ticos.pdf...
#   -> [OK] Extraído y guardado: DECRETO%201222%20DEL%2014%20DE%20NOVIEMBRE%20DE%202025%20Medios%20Democra%CC%81ticos.json
#
# --- Iniciando procesamiento de texto para: Resoluciones ---
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000388%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000176%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCIO%CC%81N%20NO%20000295%202025%20ANEXOS.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000391%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000355%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000235%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000356%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Resolucio%CC%81n%20000059%20de%202025%20Transferencia%20FAIA.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000365%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000354%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000331%20de%202024_15_12_2024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Instructivo%20Te%CC%81cnico%20Apoyo%20Directo%20Arroz%20V%202.0%20(21%20de%20julio)%20OK.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20000112%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000389%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000179%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000023%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000313%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000086%20de%202025%20Mod.%20Res.%20000016-2025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000359%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000096%20de%202025%20Pagra.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000390%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000002%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000152%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000328%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000182%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000374%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000027%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000320%20de%202025%20y%20DTS.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000383%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000352%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000377%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: MANUAL%20OPERATIVO%20PAAP%20V7%20FIRMADO.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000081%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000178%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000337%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000141%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000121%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000330%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000269%20de%202025_ZPPA%20SANTANDER.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000016%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000175%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000380%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000393%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000375%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000055%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000140%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20000111%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000392%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000125%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCIO%CC%81N%20330%20DE%202025%20-ANEXOS.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000212%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000351%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000084%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000058%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000394%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000085%20de%202025%20Libertad%20vigilada%20arroz.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000114%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000385%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Reporte%20de%20Informacio%CC%81n_Resolucio%CC%81n%20241%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000294%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000381%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: V.4%20Instructivo%20te%CC%81cnico%20programa%20apoyo%20directo%20arroz_VoBo%20Signed%20(1)%20(1).json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000052%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000397%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000242%20de%202025%20ZPPA%20CORDOBA.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000366%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000376%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000384%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000241%20de%202025%20(1).json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000373%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000331%20de%202024%20-12-12-24.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000068%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000289%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000266%20de%202025%20y%20DTS.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000180%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000169%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000174%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000123%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RES.%200057%20DE%2017%20ENE%202025%20REGLAMENTA%20ART%2055%20LEY%202294%20(2).json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000181%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000396%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000339%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000372%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Anexo%20T%C3%A9cnico%20-%20Lineamientos%20de%20Pol%C3%ADtica%20P%C3%BAblica.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCIO%CC%81N%20NO.%20000327%20DE%202025%20-%20MJ.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000378%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000214%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000177%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000069%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Resolucion_1721_julio_17_2025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000344%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000395%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000386%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000024%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000347%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000382%20de%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000231%20de%202025.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20No.%20000345%20de%202024.json
#
# --- Iniciando procesamiento de texto para: Conpes ---
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%203304%20VERSI%C3%93N%20APROBADA%20EL%202004.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%204076%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%204080%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%204067%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%204075%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Conpes%203169%20de%202012.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Conpes%203426%20de%202006.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%203316%20VERSI%C3%93N%20APROBADA%20EL%202004.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: 3958.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%204070%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%203917%20VERSI%C3%93N%20APROVADA%20EL%202018.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%204081%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%204074%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%204073%20DE%202022.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%203418%20VERSI%C3%93N%20APROBADA%20EL%202006.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%203558%20VERSI%C3%93N%20APROBADA%20EL%202008.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Conpes%203467%20de%202007.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Conpes%203616%20de%202009.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: conpes%203709%20de%202011.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%203940%20de%202018.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%203810%20VERSI%C3%93N%20APROBADA%20EL%202014.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%204066%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%203438%20VESI%C3%93N%20APROBADA%20EL%202006.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20000112%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%204069%20DE%202021.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: RESOLUCION%20000111%202024.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: Conpes%20113%20de%202008.json
#   -> [SKIP] JSON ya existe, se salta el reprocesamiento: CONPES%203859%20VERSI%C3%93N%20APROBADA%20EL%202018.json
#
# ==================================================
# RESUMEN FINAL DE EXTRACCIÓN DE TEXTO A JSON
# ==================================================
# [OK] Módulo Leyes: 59 documentos extraídos y guardados como JSON.
# [OK] Módulo Decretos: 102 documentos extraídos y guardados como JSON.
# [OK] Módulo Resoluciones: 98 documentos extraídos y guardados como JSON.
# [OK] Módulo Conpes: 28 documentos extraídos y guardados como JSON.
# ==================================================

# %% [markdown]
# # **5. Carga a MongoDB Atlas**

# %%
# Conectarse a Mongo Atlas
# Reemplazar el <db_password>
MONGO_URI = "mongodb+srv://juancd1974:Juancd1974*@cluster0.sgs4hwz.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
DB_NAME = "MINAGRICULTURA_NORMAS"
COLLECTION_NAME = "normatividad_raw"

# %%
# Carga de Datos a MongoDB Atlas

# FUNCIÓN DE CARGA

def cargar_json_a_mongo(MODULOS, BASE_DRIVE_PATH, MONGO_URI, DB_NAME, COLLECTION_NAME):

    conteo_cargados_final = {}

    try:
        # 1. Conexión a MongoDB Atlas
        client = MongoClient(MONGO_URI)
        db = client[DB_NAME]
        collection = db[COLLECTION_NAME] # Colección centralizada
        print(f"[OK] Conexión a MongoDB exitosa. Colección: {COLLECTION_NAME}")

        # Opcional pero ALTAMENTE RECOMENDADO: Crear índice para garantizar unicidad y optimizar consultas.
        collection.create_index([("documento_nombre", 1)], unique=True)
        print(f"[OK] Índice de unicidad en 'documento_nombre' creado/verificado.")

    except ConnectionError as e:
        print(f"[ERROR CONEXIÓN] Error de conexión a MongoDB: {e}")
        return conteo_cargados_final

    for modulo_nombre in MODULOS.keys():

        json_output_dir = os.path.join(BASE_DRIVE_PATH, modulo_nombre, 'json')
        contar_cargados = 0
        contar_duplicados = 0

        print(f"\n--- Iniciando carga de JSON para el módulo: {modulo_nombre} ---")

        # 2. Recorrer archivos JSON en la carpeta del módulo
        for json_archivo in os.listdir(json_output_dir):

            # FILTRO 1: Ignorar el archivo de enlaces (links.json)
            if json_archivo == 'links.json':
                print(f"  -> [SKIP] Saltando archivo de enlaces: {json_archivo}")
                continue

            if not json_archivo.endswith('.json'):
                continue

            json_path = os.path.join(json_output_dir, json_archivo)

            try:
                with open(json_path, 'r', encoding='utf-8') as json_file:
                    json_data = json.load(json_file)

                documento_nombre = json_data.get("documento_nombre")

                # FILTRO 2: Comprobación de Idempotencia
                documento_existente = collection.find_one({"documento_nombre": documento_nombre})

                if documento_existente:
                    contar_duplicados += 1
                    continue # Salta el documento si ya existe

                # 3. Insertar el documento en la colección
                insert_resultado = collection.insert_one(json_data)

                if insert_resultado.inserted_id:
                    contar_cargados += 1

            except BulkWriteError as e:
                # Captura el error si el índice único lo detecta (mecanismo de respaldo)
                if 'E11000 duplicate key error' in str(e):
                    contar_duplicados += 1
                else:
                    print(f"[ERROR CARGA] Error al cargar {json_archivo}: {e}")

            except Exception as e:
                print(f"[ERROR GENERAL] Error al procesar o cargar {json_archivo}: {e}")

        conteo_cargados_final[modulo_nombre] = {
            "cargados": contar_cargados,
            "duplicados_saltados": contar_duplicados
        }

    client.close()
    return conteo_cargados_final

# EJECUCIÓN DEL BLOQUE DE CARGA

resumen_carga = cargar_json_a_mongo(
    MODULOS_MINAGRICULTURA,
    BASE_DRIVE_PATH,
    MONGO_URI,
    DB_NAME,
    COLLECTION_NAME
)

# RESUMEN FINAL
print("\n" + "="*50)
print("RESUMEN FINAL DE CARGA A MONGODB ATLAS")
print("="*50)
if resumen_carga:
    total_cargados = 0
    total_saltados = 0
    for modulo, conteo in resumen_carga.items():
        print(f"[OK] Módulo {modulo} (Colección: {COLLECTION_NAME}):")
        print(f"   - Documentos insertados: {conteo['cargados']}")
        print(f"   - Documentos ya existentes (saltados): {conteo['duplicados_saltados']}")
        total_cargados += conteo['cargados']
        total_saltados += conteo['duplicados_saltados']

    print("-" * 50)
    print(f"TOTAL DE DOCUMENTOS NUEVOS CARGADOS: {total_cargados}")
    print(f"TOTAL DE DOCUMENTOS SALTADOS: {total_saltados}")
print("="*50)
# Out:
# [OK] Conexión a MongoDB exitosa. Colección: normatividad_raw
# [OK] Índice de unicidad en 'documento_nombre' creado/verificado.
#
# --- Iniciando carga de JSON para el módulo: Leyes ---
#   -> [SKIP] Saltando archivo de enlaces: links.json
#
# --- Iniciando carga de JSON para el módulo: Decretos ---
#   -> [SKIP] Saltando archivo de enlaces: links.json
#
# --- Iniciando carga de JSON para el módulo: Resoluciones ---
#   -> [SKIP] Saltando archivo de enlaces: links.json
#
# --- Iniciando carga de JSON para el módulo: Conpes ---
#   -> [SKIP] Saltando archivo de enlaces: links.json
#
# ==================================================
# RESUMEN FINAL DE CARGA A MONGODB ATLAS
# ==================================================
# [OK] Módulo Leyes (Colección: normatividad_raw):
#    - Documentos insertados: 0
#    - Documentos ya existentes (saltados): 59
# [OK] Módulo Decretos (Colección: normatividad_raw):
#    - Documentos insertados: 2
#    - Documentos ya existentes (saltados): 100
# [OK] Módulo Resoluciones (Colección: normatividad_raw):
#    - Documentos insertados: 0
#    - Documentos ya existentes (saltados): 98
# [OK] Módulo Conpes (Colección: normatividad_raw):
#    - Documentos insertados: 0
#    - Documentos ya existentes (saltados): 28
# --------------------------------------------------
# TOTAL DE DOCUMENTOS NUEVOS CARGADOS: 2
# TOTAL DE DOCUMENTOS SALTADOS: 285
# ==================================================
