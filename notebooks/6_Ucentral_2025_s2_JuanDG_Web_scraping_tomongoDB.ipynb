# %% [markdown]
# # **Taller para aprender a hacer Web Scraping**
# ---
# 1. Instalar librerías (básicas)
# 2. Creación de los DOOM (Página web como la vería un humano en una pantalla)
# 3. Recorrido de objetos html (página web) y vamos a recorrer los hipervínculos que esté en el dominio
# 4. Descargar todos los PDF que están linkeados/hipervinculados (acceso libre)
# 5. Extraer el texto de cada archivo PDF (normal/OCR) español y guardarlo en formato JSON
# 6. Cargar los JSON a Mongo Atlas

# %% [markdown]
# ## **0. Trabajar con Google Drive**

# %%
# Habilitamos Drive de Google desde Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **1. Instalar librerías**

# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install lxml
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (5.4.0)

# %% [markdown]
# ## **2. Crear DOOM inicial**
# * Buscar el DIV class="containerblanco"
# * Buscar todos los hipeervínculos y listar

# %%
import requests
from bs4 import BeautifulSoup

url         ='https://www.minsalud.gov.co/Normativa/Paginas/normativa.aspx'
response    =requests.get(url)
soup        =BeautifulSoup(response.content,'lxml')

# Encontrar DIV maestro clase "containerblanco"
container_div = soup.find("div", class_='containerblanco')

# Buscar todos los hipervínculos y los liste
if container_div:
    hipervinculos = container_div.find_all('a')
    for hipervinculo in hipervinculos:
        print(hipervinculo.get('href'))
else:
    print("No se encontró el DIV con la clase 'containerblanco'.")
# Out:
# None
# /Portada/index.html
# /Normativa/Paginas/decreto-unico-minsalud-780-de-2016.aspx
# /Normativa/Paginas/actos-administrativos.aspx
# http://url.minsalud.gov.co/r9qd8
# /Paginas/Norm_Conceptos.aspx
# /Normativa/Paginas/Notificaciones-por-aviso.aspx
# /Ministerio/Institucional/Paginas/asuntos-juridicos.aspx
# /Paginas/Norm_Boletines.aspx
# /Institucional/Paginas/asuntos-juridicos.aspx
# /Normativa/Paginas/Proyectos-de-actos-administrativos.aspx
# /Paginas/normograma.aspx
# /Normativa/Paginas/agenda-regulatoria.aspx
# /Normativa/Paginas/informe-global-de-participacion-ciudadana.aspx
# /Normativa/Paginas/analisis-de-impacto-normativo.aspx

# %% [markdown]
# ## **3. Crear un JSON donde se guarde los hipervínculos de cada uno de los DOOM's de las páginas hijas (aspx)**

# %% [markdown]
# ### **3.1. Librerías requeridas**

# %%
import requests
import json
import os
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %% [markdown]
# ### **3.2. Función especializada**

# %%
def extraer_hipervínculos(url):
    '''ingresr a la url cree el DOOM y extraiga los hipervínculos (aspx y PDF)'''
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
        soup = BeautifulSoup(response.content, 'lxml')
        container_div = soup.find('div', class_='containerblanco')
        links = []
        if container_div:
            for link in container_div.find_all('a'):
                href = link.get('href')
                if href:
                    full_url = urljoin(url, href)
                    # Check if the link is within the specified domain
                    if full_url.startswith("https://www.minsalud.gov.co/Normativa/"):
                        if full_url.endswith('.pdf'):
                            links.append({'url': full_url, 'type': 'pdf'})
                        elif full_url.endswith('.aspx'):
                             links.append({'url': full_url, 'type': 'aspx'})
        return links
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return []

# %% [markdown]
# ### **3.3. Crear el JSON con el web scraping**

# %%
# Load links from the existing JSON file or initialize if not found
json_file_path='/content/drive/MyDrive/BIG_DATA/WebScraping/links_minsalud.json'
if os.path.exists(json_file_path):
    try:
        with open(json_file_path, 'r') as f:
            json_data = json.load(f)
        all_links = json_data.get("links", [])
    except json.JSONDecodeError:
        print(f"Warning: {json_file_path} contains invalid JSON. Initializing with empty links.")
        all_links = []
else:
    print(f"{json_file_path} not found. Creating a new file.")
    all_links = []

# Filter initial ASPX links to visit based on the domain
aspx_links_to_visit = [link['url'] for link in all_links if link['type'] == 'aspx' and link['url'].startswith("https://www.minsalud.gov.co/Normativa/")]
visited_aspx_links = set()

# Add initial URL if the json file was empty
if not all_links:
  initial_url = "https://www.minsalud.gov.co/Normativa/Paginas/normativa.aspx"
  all_links = extraer_hipervínculos(initial_url)  #Extraer los link de la pagina inicial
  #depurar el listado (solo dejar lo aspx y pdf)
  aspx_links_to_visit = [link['url'] for link in all_links if link['type'] == 'aspx' and link['url'].startswith("https://www.minsalud.gov.co/Normativa/")]


# limpiar los link's para que solo queden los que estan en el dominio
all_links = [link for link in all_links if link['url'].startswith("https://www.minsalud.gov.co/Normativa/")]


while aspx_links_to_visit:
    current_aspx_url = aspx_links_to_visit.pop(0)
    if current_aspx_url not in visited_aspx_links:
        visited_aspx_links.add(current_aspx_url)
        print(f"Visiting: {current_aspx_url}")
        new_links = extraer_hipervínculos(current_aspx_url)
        for link in new_links:
            if link not in all_links:
                all_links.append(link)
                if link['type'] == 'aspx':
                    aspx_links_to_visit.append(link['url'])

# Create a JSON object
json_output = {"links": all_links}

# Save the JSON to a file
with open(json_file_path, 'w') as f:
    json.dump(json_output, f, indent=4)

print("finalizado extracción de links y PDF")
# Out:
# /content/drive/MyDrive/BIG_DATA/WebScraping/links_minsalud.json not found. Creating a new file.
# Visiting: https://www.minsalud.gov.co/Normativa/Paginas/decreto-unico-minsalud-780-de-2016.aspx
# Visiting: https://www.minsalud.gov.co/Normativa/Paginas/actos-administrativos.aspx
# Visiting: https://www.minsalud.gov.co/Normativa/Paginas/Notificaciones-por-aviso.aspx
# Visiting: https://www.minsalud.gov.co/Normativa/Paginas/Proyectos-de-actos-administrativos.aspx
# Visiting: https://www.minsalud.gov.co/Normativa/Paginas/agenda-regulatoria.aspx
# Visiting: https://www.minsalud.gov.co/Normativa/Paginas/informe-global-de-participacion-ciudadana.aspx
# Visiting: https://www.minsalud.gov.co/Normativa/Paginas/analisis-de-impacto-normativo.aspx
# Visiting: https://www.minsalud.gov.co/Normativa/Paginas/normativa.aspx
# finalizado extracción de links y PDF

# %% [markdown]
# ## **4. Recorrer JSON con los hipervinculos y descargar todos los PDF's**

# %%
# Define the directory to save PDFs
pdf_dir='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/'
os.makedirs(pdf_dir,exist_ok=True)

# Load the JSON file
json_file_path='/content/drive/MyDrive/BIG_DATA/WebScraping/links_minsalud.json'
try:
    with open(json_file_path, 'r') as f:
        json_data = json.load(f)
    all_links = json_data.get("links", [])
except FileNotFoundError:
    print(f"Error: {json_file_path} not found. Please run the previous step to create it.")
    all_links = []
except json.JSONDecodeError:
    print(f"Error: {json_file_path} contains invalid JSON.")
    all_links = []


# Download PDF files
for link in all_links:
    if link['type'] == 'pdf':
        pdf_url = link['url']
        try:
            response = requests.get(pdf_url, stream=True)
            response.raise_for_status()  # Raise an exception for bad status codes

            # Extract filename from the URL
            filename = os.path.join(pdf_dir, pdf_url.split('/')[-1])

            with open(filename, 'wb') as pdf_file:
                for chunk in response.iter_content(chunk_size=8192):
                    pdf_file.write(chunk)
            print(f"Downloaded: {filename}")

        except requests.exceptions.RequestException as e:
            print(f"Error downloading {pdf_url}: {e}")
        except Exception as e:
            print(f"An unexpected error occurred while processing {pdf_url}: {e}")

print("PDF download process completed.")
# Out:
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/AIN Decreto 677 de 1995 - Sección 1, 2 y 3 Versión Final para Consulta Pública + Formato observaciones AIN.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/AIN etiquetado V02032020.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/AIN etiquetado V27022020.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/AIN_Frutas Procesadas Resol 3929 de 2013 Planteamiento del problema.docx.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/AIN_Frutas Procesadas.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/AIN-BPM_DM+RDIV.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/AIN-Deficiencia de micronutrientes .pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Definición del problema AIN Alimentos para deportistas.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Informe-Rendicion-Cuentas-26-10-23.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Notificacion por Aviso Oficio Humberto Antonio Sierra Porto.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Problema AIN APME v1.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuesta consulta Problema AIN Atún en Conserva y Preparaciones de Atún en conserva.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/INFORME%20FINAL%20EX%20ANTE%20AIN%20Re%cc%81gimen%20RS%20EBC%20y%20VG%20DM%20Rev%20DNP%20F.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Cuestionario-2025-07-09T163640.894.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/INFORME%20FINAL%20EX%20ANTE%20AIN%20Re%cc%81gimen%20RS%20EBC%20y%20VG%20DM.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Consolidado%20Observaciones%20EX%20ANT%20AIN%20Regime%cc%81n%20RS%20EBC%20Y%20VS.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/BPL-ContCal-Farma-Informe-Evaluacion.pdf.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Document%20-%202024-12-30T110952.411.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Document%20-%202024-12-09T181349.355.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/238820241107100510321.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/286320241107105020741.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/AIN%20Dec%20677%20de%201995_VERSION%20FINAL%2019-Ago-2022.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuesta%20a%20consolidado%20de%20comentarios%20AIN%20RRSM%2019-Ago-2022.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Regimen-de-registros-sanitarios-permisos-de-comercializacion-y-fiscalizacion-sanitaria-de-DM.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/AIN%20BPM%20DM%20RDIV_20240624165244.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/2024%2006%2006%20Minsalud%20-%20Concepto%20y%20ru%cc%81brica%20AIN%20completo%20-%20BPM%20DM%20RDIV_20240624165428.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/memoria-justificativa-266220240624185959472.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuesta%20a%20comentarios%20AIN%20expost%20R.2674%20de%202013_240724%20%281%29.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/AIN%20final%20grasas%20trans.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Informe%20Consulta%20AIN%20Completo%20APME.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/AIN_APME_VF.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/An%c3%a1lisis%20de%20impacto%20normativo%20en%20la%20tem%c3%a1tica%20de%20alimentos%20para%20deportistas.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/AIN%20Decreto%20677%20de%201995%20-%20Secci%c3%b3n%201%2c%202%20y%203%20Versi%c3%b3n%20Final%20para%20Consulta%20P%c3%bablica%20+%20Formato%20observaciones%20AIN.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuetas%20observaciones%20AIN%20Sodio.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Informe%20consulta%20definici%c3%b3n%20del%20problema%20del%20AIN%20%20etiquetado.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuestas%20a%20observaciones%20AIN%20etiquetado%20VF.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuesta%20consulta%20Problema%20-%20Bebidas%20Alcoho%cc%81licas.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuesta%20a%20consulta%20pu%cc%81blica%20de%20Ana%cc%81lisis%20de%20impacto%20normativo.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuesta%20a%20observaciones%20AIN%20-%20prevencion%20y%20control%20de%20deficiencia%20de%20micronutrientes.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuesta%20a%20consuta%20publica%20AIN%20micronutrientes.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/RESPUESTAS%20A%20CONSULTA%20PUBLICA%20ANALISIS%20DE%20PROBLEMA%20-%20AIN%20SAL%20PARA%20CONSUMO%20HUMANO.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Informe%20de%20participacion%20AIN%20Sal%20para%20consumo%20humano.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuestas%20observaciones%20Problema%20AIN%20BEnergizantes%2005.08.20.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuesta%20consulta%20Problema%20AIN%20At%c3%ban%20en%20Conserva%20y%20Preparaciones%20de%20At%c3%ban%20en%20conserva.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Atun%20Formato%20para%20observaciones%20AIN%20final.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Observaciones%20AIN%20VAJILLAS%20sep.15%20publica.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Observaciones%20AIN%20VAJILLAS%20total.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Informe%20Consulta%20Definicio%cc%81n%20del%20Problema%20AIN%20APME.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuestas%20observaciones%20problema%20AIN%20pinturas%20%2808-jul-2021%29.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Respuestas%20AIN%20alimentos%20infantiles.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Anexo%203_Rta%20Consulta%20lacteos.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Informe%20Consulta%20p%c3%bablica%20Evaluaci%c3%b3n%20ex%20post%20Suplementos%20dietarios.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/observaciones%20consulta%20publica%20AIN%20Decreto%20616%20de%202006.pdf
# Downloaded: /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/Informe%20deportistas%20consulta.pdf
# PDF download process completed.

# %% [markdown]
# ## **5. Extraer el texto de cada archivo PDF y generar un JSON**

# %% [markdown]
# ### **5.1. Instalar librerías especializadas para trabajar con PDF (OCR)**

# %%
# !apt-get update
# !apt-get install tesseract-ocr libtesseract-dev tesseract-ocr-spa
# !apt-get install poppler-utils

# Instalar librerías para trabajar con imágenes
# !pip install pytesseract Pillow
# !pip install matplotlib-venn
# !pip install pdfminer.six pdf2image
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 129 kB in 1s (106 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# tesseract-ocr-spa is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.11 [186 kB]
# Fetched 186 kB in 0s (774 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126812 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.11_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.11) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.11) ...
# Processing triggers for man-db (2.10.2-1) ...
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (25.0)
# Requirement already satisfied: matplotlib-venn in /usr/local/lib/python3.12/dist-packages (1.1.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from matplotlib-venn) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from matplotlib-venn) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from matplotlib-venn) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.17.0)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.12/dist-packages (20250506)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.12/dist-packages (1.17.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six) (3.4.3)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six) (43.0.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from pdf2image) (11.3.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.23)

# %% [markdown]
# ### **5.2. Instanciar las librerías que necesitamos**

# %%
import pytesseract
from io import StringIO
from datetime import datetime
from PIL import Image, ImageOps
# Librerías para trabajar con PDF
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage

# %% [markdown]
# ### **5.3. Extraer el texto a un archivo JSON**

# %%
def extraer_texto_desde_pdf (pdf_path):
    # Intento de extracción NORMAL
    try:
        rsrcmgr = PDFResourceManager()
        retstr = StringIO()
        codec = 'utf-8'
        laparams = LAParams()
        device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
        fp = open(pdf_path, 'rb')
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        for page in PDFPage.get_pages(fp, caching=True, check_extractable=True):
            interpreter.process_page(page)
        text = retstr.getvalue()
        fp.close()
        device.close()
        retstr.close()

        if text.strip():                # Check if standard extraction yielded any text
            return text, 'normal', True

    except Exception as e:
        print (f"Error al extraer texto desde {pdf_path}: {e}")

    # Si no puedo por el método normal intente con OCR
    try:
        from pdf2image import convert_from_path
        images = convert_from_path(pdf_path)
        ocr_text = ""
        for i, image in enumerate (images):
            ocr_text += pytesseract.image_to_string(image, lang='spa')
        if ocr_text.strip():
                return ocr_text, 'OCR', True
        else:
            print(f"No se pudo extraer texto con OCR de {pdf_path}")
            return "", 'OCR', False
    except Exception as e:
        print (f"Error al extraer texto con OCR {pdf_path}: {e}")
    return "", "Failed", False

# %%
# Define input and output directories
pdf_dir='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_pdfs/'
json_output_dir='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/'
error_json_path='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_error.json'
os.makedirs(json_output_dir,exist_ok=True)      # Crear la carpeta si no existe

pdf_archivos = [f for f in os.listdir(pdf_dir) if f.endswith('.pdf')]
error_archivos=[]

# Procesar cada archivo pdf
for i, pdf_archivo in enumerate(pdf_archivos):
    print(f"Procesando archivo {i+1}/{len(pdf_archivos)}:{pdf_archivo}")
    pdf_path = os.path.join(pdf_dir, pdf_archivo)
    texto, metodo, sucess = extraer_texto_desde_pdf(pdf_path)

    if sucess:          # Create JSON data
        json_data ={
            "archivo": pdf_archivo,
            "fecha": datetime.now().strftime("%Y-%m-%d"),
            "texto": texto,
            "metodo": metodo
        }

        # Guardar un archivo JSON con una secuencia
        json_file = f"Minsalud_{i+1}.json"
        json_file_path = os.path.join(json_output_dir, json_file)
        with open(json_file_path, 'w', encoding='utf-8') as json_file:
            json.dump(json_data, json_file, indent=4, ensure_ascii=False)
        print(f"PDF {pdf_archivo} => JSON creado: {json_file}")
    else:
        error_archivos.append(pdf_archivo)
        print(f"Error al procesar {pdf_archivo}")

# Save the list of error files to a JSON file
if len(error_archivos) > 0:
    error_json_data = {"archivos_error": error_archivos}
    with open(error_json_path, 'w', encoding='utf-8') as json_file:
        json.dump(error_json_data, json_file, indent=4, ensure_ascii=False)
    print(f"Lista de archivos con errores guardada en {error_json_path}")


print("Extracción de texto PDF y creación de JSON completadas.")
print(f"Lista de archivos con errores guardada en {error_json_path}")
# Out:
# Procesando archivo 1/54:AIN Decreto 677 de 1995 - Sección 1, 2 y 3 Versión Final para Consulta Pública + Formato observaciones AIN.pdf
# PDF AIN Decreto 677 de 1995 - Sección 1, 2 y 3 Versión Final para Consulta Pública + Formato observaciones AIN.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_1.json' mode='w' encoding='utf-8'>
# Procesando archivo 2/54:AIN etiquetado V02032020.pdf
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P386' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P394' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P402' is an invalid float value
# PDF AIN etiquetado V02032020.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_2.json' mode='w' encoding='utf-8'>
# Procesando archivo 3/54:AIN etiquetado V27022020.pdf
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P398' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P406' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P414' is an invalid float value
# PDF AIN etiquetado V27022020.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_3.json' mode='w' encoding='utf-8'>
# Procesando archivo 4/54:AIN_Frutas Procesadas Resol 3929 de 2013 Planteamiento del problema.docx.pdf
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P233' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P239' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P245' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P251' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P280' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P286' is an invalid float value
# PDF AIN_Frutas Procesadas Resol 3929 de 2013 Planteamiento del problema.docx.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_4.json' mode='w' encoding='utf-8'>
# Procesando archivo 5/54:AIN_Frutas Procesadas.pdf
# PDF AIN_Frutas Procesadas.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_5.json' mode='w' encoding='utf-8'>
# Procesando archivo 6/54:AIN-BPM_DM+RDIV.pdf
# PDF AIN-BPM_DM+RDIV.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_6.json' mode='w' encoding='utf-8'>
# Procesando archivo 7/54:AIN-Deficiencia de micronutrientes .pdf
# PDF AIN-Deficiencia de micronutrientes .pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_7.json' mode='w' encoding='utf-8'>
# Procesando archivo 8/54:Definición del problema AIN Alimentos para deportistas.pdf
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# PDF Definición del problema AIN Alimentos para deportistas.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_8.json' mode='w' encoding='utf-8'>
# Procesando archivo 9/54:Informe-Rendicion-Cuentas-26-10-23.pdf
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P1' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P2' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P0' is an invalid float value
# ...
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P372' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P378' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P384' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P390' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P396' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P402' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P408' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P414' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P420' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P426' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P447' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P453' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P459' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P465' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P471' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P477' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P483' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P489' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P495' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P501' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P520' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P526' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P532' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P538' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P544' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P550' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P568' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P574' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P580' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P586' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P592' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P598' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P604' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P610' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P616' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P626' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P639' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P643' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P646' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P649' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P652' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P667' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P673' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P679' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P687' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P693' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P699' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P705' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P711' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P717' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P723' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P731' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P740' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P741' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P742' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P745' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P760' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P771' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P772' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P773' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P774' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P775' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P780' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P793' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P794' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P795' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P796' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P797' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P802' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P811' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P812' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P813' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P814' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P870' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P878' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P884' is an invalid float value
# PDF AIN_APME_VF.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_31.json' mode='w' encoding='utf-8'>
# Procesando archivo 32/54:An%c3%a1lisis%20de%20impacto%20normativo%20en%20la%20tem%c3%a1tica%20de%20alimentos%20para%20deportistas.pdf
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P334' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P342' is an invalid float value
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P348' is an invalid float value
# PDF An%c3%a1lisis%20de%20impacto%20normativo%20en%20la%20tem%c3%a1tica%20de%20alimentos%20para%20deportistas.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_32.json' mode='w' encoding='utf-8'>
# Procesando archivo 33/54:AIN%20Decreto%20677%20de%201995%20-%20Secci%c3%b3n%201%2c%202%20y%203%20Versi%c3%b3n%20Final%20para%20Consulta%20P%c3%bablica%20+%20Formato%20observaciones%20AIN.pdf
# PDF AIN%20Decreto%20677%20de%201995%20-%20Secci%c3%b3n%201%2c%202%20y%203%20Versi%c3%b3n%20Final%20para%20Consulta%20P%c3%bablica%20+%20Formato%20observaciones%20AIN.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_33.json' mode='w' encoding='utf-8'>
# Procesando archivo 34/54:Respuetas%20observaciones%20AIN%20Sodio.pdf
# PDF Respuetas%20observaciones%20AIN%20Sodio.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_34.json' mode='w' encoding='utf-8'>
# Procesando archivo 35/54:Informe%20consulta%20definici%c3%b3n%20del%20problema%20del%20AIN%20%20etiquetado.pdf
# PDF Informe%20consulta%20definici%c3%b3n%20del%20problema%20del%20AIN%20%20etiquetado.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_35.json' mode='w' encoding='utf-8'>
# Procesando archivo 36/54:Respuestas%20a%20observaciones%20AIN%20etiquetado%20VF.pdf
# PDF Respuestas%20a%20observaciones%20AIN%20etiquetado%20VF.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_36.json' mode='w' encoding='utf-8'>
# Procesando archivo 37/54:Respuesta%20consulta%20Problema%20-%20Bebidas%20Alcoho%cc%81licas.pdf
# PDF Respuesta%20consulta%20Problema%20-%20Bebidas%20Alcoho%cc%81licas.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_37.json' mode='w' encoding='utf-8'>
# Procesando archivo 38/54:Respuesta%20a%20consulta%20pu%cc%81blica%20de%20Ana%cc%81lisis%20de%20impacto%20normativo.pdf
# PDF Respuesta%20a%20consulta%20pu%cc%81blica%20de%20Ana%cc%81lisis%20de%20impacto%20normativo.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_38.json' mode='w' encoding='utf-8'>
# Procesando archivo 39/54:Respuesta%20a%20observaciones%20AIN%20-%20prevencion%20y%20control%20de%20deficiencia%20de%20micronutrientes.pdf
# PDF Respuesta%20a%20observaciones%20AIN%20-%20prevencion%20y%20control%20de%20deficiencia%20de%20micronutrientes.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_39.json' mode='w' encoding='utf-8'>
# Procesando archivo 40/54:Respuesta%20a%20consuta%20publica%20AIN%20micronutrientes.pdf
# PDF Respuesta%20a%20consuta%20publica%20AIN%20micronutrientes.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_40.json' mode='w' encoding='utf-8'>
# Procesando archivo 41/54:RESPUESTAS%20A%20CONSULTA%20PUBLICA%20ANALISIS%20DE%20PROBLEMA%20-%20AIN%20SAL%20PARA%20CONSUMO%20HUMANO.pdf
# PDF RESPUESTAS%20A%20CONSULTA%20PUBLICA%20ANALISIS%20DE%20PROBLEMA%20-%20AIN%20SAL%20PARA%20CONSUMO%20HUMANO.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_41.json' mode='w' encoding='utf-8'>
# Procesando archivo 42/54:Informe%20de%20participacion%20AIN%20Sal%20para%20consumo%20humano.pdf
# PDF Informe%20de%20participacion%20AIN%20Sal%20para%20consumo%20humano.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_42.json' mode='w' encoding='utf-8'>
# Procesando archivo 43/54:Respuestas%20observaciones%20Problema%20AIN%20BEnergizantes%2005.08.20.pdf
# PDF Respuestas%20observaciones%20Problema%20AIN%20BEnergizantes%2005.08.20.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_43.json' mode='w' encoding='utf-8'>
# Procesando archivo 44/54:Respuesta%20consulta%20Problema%20AIN%20At%c3%ban%20en%20Conserva%20y%20Preparaciones%20de%20At%c3%ban%20en%20conserva.pdf
# PDF Respuesta%20consulta%20Problema%20AIN%20At%c3%ban%20en%20Conserva%20y%20Preparaciones%20de%20At%c3%ban%20en%20conserva.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_44.json' mode='w' encoding='utf-8'>
# Procesando archivo 45/54:Atun%20Formato%20para%20observaciones%20AIN%20final.pdf
# PDF Atun%20Formato%20para%20observaciones%20AIN%20final.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_45.json' mode='w' encoding='utf-8'>
# Procesando archivo 46/54:Observaciones%20AIN%20VAJILLAS%20sep.15%20publica.pdf
# PDF Observaciones%20AIN%20VAJILLAS%20sep.15%20publica.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_46.json' mode='w' encoding='utf-8'>
# Procesando archivo 47/54:Observaciones%20AIN%20VAJILLAS%20total.pdf
# PDF Observaciones%20AIN%20VAJILLAS%20total.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_47.json' mode='w' encoding='utf-8'>
# Procesando archivo 48/54:Informe%20Consulta%20Definicio%cc%81n%20del%20Problema%20AIN%20APME.pdf
# PDF Informe%20Consulta%20Definicio%cc%81n%20del%20Problema%20AIN%20APME.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_48.json' mode='w' encoding='utf-8'>
# Procesando archivo 49/54:Respuestas%20observaciones%20problema%20AIN%20pinturas%20%2808-jul-2021%29.pdf
# PDF Respuestas%20observaciones%20problema%20AIN%20pinturas%20%2808-jul-2021%29.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_49.json' mode='w' encoding='utf-8'>
# Procesando archivo 50/54:Respuestas%20AIN%20alimentos%20infantiles.pdf
# PDF Respuestas%20AIN%20alimentos%20infantiles.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_50.json' mode='w' encoding='utf-8'>
# Procesando archivo 51/54:Anexo%203_Rta%20Consulta%20lacteos.pdf
# PDF Anexo%203_Rta%20Consulta%20lacteos.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_51.json' mode='w' encoding='utf-8'>
# Procesando archivo 52/54:Informe%20Consulta%20p%c3%bablica%20Evaluaci%c3%b3n%20ex%20post%20Suplementos%20dietarios.pdf
# PDF Informe%20Consulta%20p%c3%bablica%20Evaluaci%c3%b3n%20ex%20post%20Suplementos%20dietarios.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_52.json' mode='w' encoding='utf-8'>
# Procesando archivo 53/54:observaciones%20consulta%20publica%20AIN%20Decreto%20616%20de%202006.pdf
# PDF observaciones%20consulta%20publica%20AIN%20Decreto%20616%20de%202006.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_53.json' mode='w' encoding='utf-8'>
# Procesando archivo 54/54:Informe%20deportistas%20consulta.pdf
# PDF Informe%20deportistas%20consulta.pdf => JSON creado: <_io.TextIOWrapper name='/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/Minsalud_54.json' mode='w' encoding='utf-8'>
# Extracción de texto PDF y creación de JSON completadas.
# Lista de archivos con errores guardada en /content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_error.json

# %% [markdown]
# ## **6. Cargar los JSON a Mongo Atlas**

# %% [markdown]
# ### **6.1. Instalar librerías**

# %%
# Instalar librerías de Mongo
# !pip install pymongo
# !pip install py2neo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.15.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.15.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 23.4 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 24.3 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.15.3
# Collecting py2neo
#   Downloading py2neo-2021.2.4-py2.py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from py2neo) (2025.10.5)
# Collecting interchange~=2021.0.4 (from py2neo)
#   Downloading interchange-2021.0.4-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting monotonic (from py2neo)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from py2neo) (25.0)
# Collecting pansi>=2020.7.3 (from py2neo)
#   Downloading pansi-2024.11.0-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: pygments>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from py2neo) (2.19.2)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from py2neo) (1.17.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from py2neo) (2.5.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from interchange~=2021.0.4->py2neo) (2025.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from pansi>=2020.7.3->py2neo) (11.3.0)
# Downloading py2neo-2021.2.4-py2.py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 4.3 MB/s eta 0:00:00
# Downloading interchange-2021.0.4-py2.py3-none-any.whl (28 kB)
# Downloading pansi-2024.11.0-py2.py3-none-any.whl (26 kB)
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Installing collected packages: monotonic, pansi, interchange, py2neo
# Successfully installed interchange-2021.0.4 monotonic-1.6 pansi-2024.11.0 py2neo-2021.2.4

# %% [markdown]
# ### **6.2. Establecer conexión a Mongo**

# %%
from pymongo import MongoClient

# Conectarse a Mongo Atlas
# Reemplazar el <db_password>
uri = "mongodb+srv://juancd1974:xxxxxxx@cluster0.sgs4hwz.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client=MongoClient(uri)
client.stats
# Out:
# Database(MongoClient(host=['ac-8e0mhdx-shard-00-02.sgs4hwz.mongodb.net:27017', 'ac-8e0mhdx-shard-00-01.sgs4hwz.mongodb.net:27017', 'ac-8e0mhdx-shard-00-00.sgs4hwz.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-14lj6v-shard-0', tls=True), 'stats')

# %% [markdown]
# ### **6.3. Crear una base de datos (Minsalud)**

# %%
# Crear la Base de datos
db_name = 'minsalud_db'
db = client[db_name]

# Crear la colección
collection_name = 'normatividad'
collection = db[collection_name]
print(f"Base de datos {db_name} y colección {collection_name} creadas")
# Out:
# Base de datos minsalud_db y colección normatividad creadas

# %% [markdown]
# ### **6.4. Cargar archivos JSON a colección**

# %%
import os
import json
from pymongo.errors import PyMongoError

# Cargar los archivos JSON a la colección en mongo Atlas
json_output_dir = '/content/drive/MyDrive/BIG_DATA/WebScraping/Minsalud_json/'
json_archivos = [f for f in os.listdir(json_output_dir) if f.endswith('.json')]

contar_cargados = 0
json_no_cargados =[]
print(f"Cargando {len(json_archivos)} JSON a Mongo")

for json_archivo in json_archivos:
    json_path = os.path.join(json_output_dir, json_archivo)
    try:
        with open (json_path, 'r', encoding='utf-8') as json_file:
            json_data = json.load(json_file)

        # Insert the data into the collection
        insert_resultado = collection.insert_one(json_data)

        if insert_resultado.inserted_id:
            print(f"JSON {json_archivo} cargado correctamente. ID: {insert_resultado.inserted_id}")
            contar_cargados+=1
        else:
            print(f"Error al cargar {json_archivo}")
            json_no_cargados.append(json_archivo)

    except FileNotFoundError:
        print(f"Error: File not found at {json_path}")
        json_no_cargados.append(json_file)
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON in file {json_file}")
        json_no_cargados.append(json_file)
    except PyMongoError as e:
        print(f"MongoDB error while loading {json_file}: {e}")
        json_no_cargados.append(json_file)
    except Exception as e:
        print(f"An unexpected error occurred while processing {json_file}: {e}")
        json_no_cargados.append(json_file)

print(f"JSON cargados: {contar_cargados} de {len(json_archivos)}")
if json_no_cargados:
    print(f"JSON no cargados: {json_no_cargados}")
# Out:
# Cargando 54 JSON a Mongo
# JSON Minsalud_1.json cargado correctamente. ID: 68eea26fda2543ca181c3c85
# JSON Minsalud_2.json cargado correctamente. ID: 68eea270da2543ca181c3c86
# JSON Minsalud_3.json cargado correctamente. ID: 68eea270da2543ca181c3c87
# JSON Minsalud_4.json cargado correctamente. ID: 68eea270da2543ca181c3c88
# JSON Minsalud_5.json cargado correctamente. ID: 68eea270da2543ca181c3c89
# JSON Minsalud_6.json cargado correctamente. ID: 68eea270da2543ca181c3c8a
# JSON Minsalud_7.json cargado correctamente. ID: 68eea270da2543ca181c3c8b
# JSON Minsalud_8.json cargado correctamente. ID: 68eea270da2543ca181c3c8c
# JSON Minsalud_9.json cargado correctamente. ID: 68eea270da2543ca181c3c8d
# JSON Minsalud_10.json cargado correctamente. ID: 68eea271da2543ca181c3c8e
# JSON Minsalud_11.json cargado correctamente. ID: 68eea271da2543ca181c3c8f
# JSON Minsalud_12.json cargado correctamente. ID: 68eea271da2543ca181c3c90
# JSON Minsalud_13.json cargado correctamente. ID: 68eea271da2543ca181c3c91
# JSON Minsalud_14.json cargado correctamente. ID: 68eea271da2543ca181c3c92
# JSON Minsalud_15.json cargado correctamente. ID: 68eea271da2543ca181c3c93
# JSON Minsalud_16.json cargado correctamente. ID: 68eea271da2543ca181c3c94
# JSON Minsalud_17.json cargado correctamente. ID: 68eea271da2543ca181c3c95
# JSON Minsalud_18.json cargado correctamente. ID: 68eea271da2543ca181c3c96
# JSON Minsalud_19.json cargado correctamente. ID: 68eea271da2543ca181c3c97
# JSON Minsalud_20.json cargado correctamente. ID: 68eea272da2543ca181c3c98
# JSON Minsalud_21.json cargado correctamente. ID: 68eea272da2543ca181c3c99
# JSON Minsalud_22.json cargado correctamente. ID: 68eea272da2543ca181c3c9a
# JSON Minsalud_23.json cargado correctamente. ID: 68eea272da2543ca181c3c9b
# JSON Minsalud_24.json cargado correctamente. ID: 68eea272da2543ca181c3c9c
# JSON Minsalud_25.json cargado correctamente. ID: 68eea272da2543ca181c3c9d
# JSON Minsalud_26.json cargado correctamente. ID: 68eea272da2543ca181c3c9e
# JSON Minsalud_27.json cargado correctamente. ID: 68eea272da2543ca181c3c9f
# JSON Minsalud_28.json cargado correctamente. ID: 68eea272da2543ca181c3ca0
# JSON Minsalud_29.json cargado correctamente. ID: 68eea272da2543ca181c3ca1
# JSON Minsalud_30.json cargado correctamente. ID: 68eea272da2543ca181c3ca2
# JSON Minsalud_31.json cargado correctamente. ID: 68eea272da2543ca181c3ca3
# JSON Minsalud_32.json cargado correctamente. ID: 68eea272da2543ca181c3ca4
# JSON Minsalud_33.json cargado correctamente. ID: 68eea272da2543ca181c3ca5
# JSON Minsalud_34.json cargado correctamente. ID: 68eea272da2543ca181c3ca6
# JSON Minsalud_35.json cargado correctamente. ID: 68eea272da2543ca181c3ca7
# JSON Minsalud_36.json cargado correctamente. ID: 68eea273da2543ca181c3ca8
# JSON Minsalud_37.json cargado correctamente. ID: 68eea273da2543ca181c3ca9
# JSON Minsalud_38.json cargado correctamente. ID: 68eea273da2543ca181c3caa
# JSON Minsalud_39.json cargado correctamente. ID: 68eea273da2543ca181c3cab
# JSON Minsalud_40.json cargado correctamente. ID: 68eea273da2543ca181c3cac
# JSON Minsalud_41.json cargado correctamente. ID: 68eea273da2543ca181c3cad
# JSON Minsalud_42.json cargado correctamente. ID: 68eea273da2543ca181c3cae
# JSON Minsalud_43.json cargado correctamente. ID: 68eea273da2543ca181c3caf
# JSON Minsalud_44.json cargado correctamente. ID: 68eea273da2543ca181c3cb0
# JSON Minsalud_45.json cargado correctamente. ID: 68eea273da2543ca181c3cb1
# JSON Minsalud_46.json cargado correctamente. ID: 68eea273da2543ca181c3cb2
# JSON Minsalud_47.json cargado correctamente. ID: 68eea273da2543ca181c3cb3
# JSON Minsalud_48.json cargado correctamente. ID: 68eea273da2543ca181c3cb4
# JSON Minsalud_49.json cargado correctamente. ID: 68eea273da2543ca181c3cb5
# JSON Minsalud_50.json cargado correctamente. ID: 68eea273da2543ca181c3cb6
# JSON Minsalud_51.json cargado correctamente. ID: 68eea273da2543ca181c3cb7
# JSON Minsalud_52.json cargado correctamente. ID: 68eea273da2543ca181c3cb8
# JSON Minsalud_53.json cargado correctamente. ID: 68eea273da2543ca181c3cb9
# JSON Minsalud_54.json cargado correctamente. ID: 68eea273da2543ca181c3cba
# JSON cargados: 54 de 54
# JSON no cargados: []
